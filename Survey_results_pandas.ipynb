# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd

# %%
df =pd.read_csv('survey_results_public.csv')

# %%
##USED TO DISPLAY ALL COLUMNS

print('DISPLAY ALL COLUMNS')
df.columns
# Out:
# DISPLAY ALL COLUMNS
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
##USED TO DISPlAY THE FIRST 5 RECORDS
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
##USED TO DISPLAY THE LAST 5 RECORDS
df.tail()
# Out:
#        Respondent MainBranch Hobbyist  \
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
##USED TO DISPLAY THE TOTAL NO OF ROWS AND COLUMNS
df.shape
# Out:
# (88883, 85)

# %%
df.size
# Out:
# 7555055

# %%
##USED TO DISPLAY THE INFO ABOUT THE COLUMNS
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
##DISPLAY THE HOBBYIST COLUMN NAME WITH ITS RECORD
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
##USED TO DISPLAY THE TOTAL NO OF YES AND NO IN HOBBYIST COLUMN
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
##USED TO CHANGE THE COLUMN NAME IN UPPERCASE
df.columns_upper=[x.upper() for x in df.columns]
df.columns_upper
# Out:
# C:\Users\t\AppData\Local\Temp\ipykernel_8388\2898348819.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.columns_upper=[x.upper() for x in df.columns]
# ['RESPONDENT',
#  'MAINBRANCH',
#  'HOBBYIST',
#  'OPENSOURCER',
#  'OPENSOURCE',
#  'EMPLOYMENT',
#  'COUNTRY',
#  'STUDENT',
#  'EDLEVEL',
#  'UNDERGRADMAJOR',
#  'EDUOTHER',
#  'ORGSIZE',
#  'DEVTYPE',
#  'YEARSCODE',
#  'AGE1STCODE',
#  'YEARSCODEPRO',
#  'CAREERSAT',
#  'JOBSAT',
#  'MGRIDIOT',
#  'MGRMONEY',
#  'MGRWANT',
#  'JOBSEEK',
#  'LASTHIREDATE',
#  'LASTINT',
#  'FIZZBUZZ',
#  'JOBFACTORS',
#  'RESUMEUPDATE',
#  'CURRENCYSYMBOL',
#  'CURRENCYDESC',
#  'COMPTOTAL',
#  'COMPFREQ',
#  'CONVERTEDCOMP',
#  'WORKWEEKHRS',
#  'WORKPLAN',
#  'WORKCHALLENGE',
#  'WORKREMOTE',
#  'WORKLOC',
#  'IMPSYN',
#  'CODEREV',
#  'CODEREVHRS',
#  'UNITTESTS',
#  'PURCHASEHOW',
#  'PURCHASEWHAT',
# ...

# %%
##TO RENAME THE COLUMNS
df.rename(columns ={'Respondent':'Resp','Hobbyist':'Hobby'})
# Out:
#         Resp                                         MainBranch Hobby  \
# 0          1             I am a student who is learning to code   Yes
# 1          2             I am a student who is learning to code    No
# 2          3  I am not primarily a developer, but I write co...   Yes
# 3          4                     I am a developer by profession    No
# 4          5                     I am a developer by profession   Yes
# ...      ...                                                ...   ...
# 88878  88377                                                NaN   Yes
# 88879  88601                                                NaN    No
# 88880  88802                                                NaN    No
# 88881  88816                                                NaN    No
# 88882  88863                                                NaN   Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# ...

# %%
##ACTUAL COLUMN NAME DOESNT AFFECTED WHEN RENAME THE COLUMN
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
##USED TO DISPLAY THE ROWS FROM 0 TO 9(INDEX VALUE FROM 0 TO 9 RECORDS)
df.loc[:9]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# ...

# %%
##USED TO DISPLAY THE ROWS WITH INDEX FROM 1 TO 3 ALONG WITH RECORDS IN THE Hobbyist COLUMN
df.loc[1:3,['Country']]
# Out:
#                   Country
# 1  Bosnia and Herzegovina
# 2                Thailand
# 3           United States

# %%
##USED TO CHANGE THE RECORDS IN A PARTICULAR ROW AND COLUMN
df.loc[2,['Country']]=['INDIA']

# %%
df.loc[2,['Country']]
# Out:
# Country    INDIA
# Name: 2, dtype: object

# %%
##USED TO CHANGE THE COUNTRYS IN LOWER CASE
df['Country'].str.lower()
# Out:
# 0                united kingdom
# 1        bosnia and herzegovina
# 2                         india
# 3                 united states
# 4                       ukraine
#                   ...
# 88878                    canada
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
# 88882                     spain
# Name: Country, Length: 88883, dtype: object

# %%
##USED TO SET THE INDEX VALUE AS COUNTRY
##ACTUAL INDEX REMAINS UNCHANGED
df_country_index=df.set_index('Country')
df_country_index
# Out:
#                         Respondent  \
# Country
# United Kingdom                   1
# Bosnia and Herzegovina           2
# INDIA                            3
# United States                    4
# Ukraine                          5
# ...                            ...
# Canada                       88377
# NaN                          88601
# NaN                          88802
# NaN                          88816
# Spain                        88863
#
#                                                                MainBranch  \
# Country
# United Kingdom                     I am a student who is learning to code
# Bosnia and Herzegovina             I am a student who is learning to code
# INDIA                   I am not primarily a developer, but I write co...
# United States                              I am a developer by profession
# Ukraine                                    I am a developer by profession
# ...

# %%
##USED TO CHANGE THE DEFAULT INDEX AS COUNTRY FOR ACTUAL DATA
df.set_index('Country',inplace = True)

# %%
df
# Out:
#                         Respondent  \
# Country
# United Kingdom                   1
# Bosnia and Herzegovina           2
# INDIA                            3
# United States                    4
# Ukraine                          5
# ...                            ...
# Canada                       88377
# NaN                          88601
# NaN                          88802
# NaN                          88816
# Spain                        88863
#
#                                                                MainBranch  \
# Country
# United Kingdom                     I am a student who is learning to code
# Bosnia and Herzegovina             I am a student who is learning to code
# INDIA                   I am not primarily a developer, but I write co...
# United States                              I am a developer by profession
# Ukraine                                    I am a developer by profession
# ...

# %%
##Used to reset the index value from 0
df.reset_index(inplace =True)

# %%
df
# Out:
#                       Country  Respondent  \
# 0              United Kingdom           1
# 1      Bosnia and Herzegovina           2
# 2                       INDIA           3
# 3               United States           4
# 4                     Ukraine           5
# ...                       ...         ...
# 88878                  Canada       88377
# 88879                     NaN       88601
# 88880                     NaN       88802
# 88881                     NaN       88816
# 88882                   Spain       88863
#
#                                               MainBranch Hobbyist  \
# 0                 I am a student who is learning to code      Yes
# 1                 I am a student who is learning to code       No
# 2      I am not primarily a developer, but I write co...      Yes
# 3                         I am a developer by profession       No
# 4                         I am a developer by profession      Yes
# ...

# %%
##USED TO GET THE REQUIRED DATA TO BE STORED IN df_nostudent
df_nostudent=(df['Student']=='No')
df_nostudent.value_counts()
# Out:
# True     65816
# False    23067
# Name: Student, dtype: int64

# %%
##USED TO DISPLAY THE RESULTS WITH ALL RECORDS
df_students_no =df[df_nostudent]
df_students_no
# Out:
#               Country  Respondent  \
# 0      United Kingdom           1
# 2               INDIA           3
# 3       United States           4
# 4             Ukraine           5
# 5              Canada           6
# ...               ...         ...
# 88866       Australia       86638
# 88870     Netherlands       87352
# 88876           Spain       88212
# 88877   United States       88282
# 88878          Canada       88377
#
#                                               MainBranch Hobbyist  \
# 0                 I am a student who is learning to code      Yes
# 2      I am not primarily a developer, but I write co...      Yes
# 3                         I am a developer by profession       No
# 4                         I am a developer by profession      Yes
# 5      I am not primarily a developer, but I write co...      Yes
# ...                                                  ...      ...
# 88866                                                NaN      Yes
# ...

# %%
##USED TO DISPLAY THE OPPOSITE RESULTS
df_students_yes = df[~df_nostudent]
df_students_yes
# Out:
#                       Country  Respondent  \
# 1      Bosnia and Herzegovina           2
# 7                       India           8
# 10        Antigua and Barbuda          11
# 11                     Canada          12
# 14                      India          15
# ...                       ...         ...
# 88875                Pakistan       88182
# 88879                     NaN       88601
# 88880                     NaN       88802
# 88881                     NaN       88816
# 88882                   Spain       88863
#
#                                    MainBranch Hobbyist  \
# 1      I am a student who is learning to code       No
# 7                 I code primarily as a hobby      Yes
# 10                I code primarily as a hobby      Yes
# 11     I am a student who is learning to code       No
# 14     I am a student who is learning to code      Yes
# ...                                       ...      ...
# 88875                                     NaN      Yes
# ...

# %%
##USED TO DISPLAY ALL THE RECORDS WHOSE ConvertedComp IS GREATER THAN 700000
df_high_salary = (df['ConvertedComp']>70000)
df[df_high_salary]
# Out:
#               Country  Respondent  \
# 5              Canada           6
# 8         New Zealand           9
# 12      United States          13
# 15     United Kingdom          16
# 21      United States          22
# ...               ...         ...
# 88323   United States       88876
# 88324   United States       88877
# 88325   United States       88878
# 88326         Finland       88879
# 88329     Netherlands       88882
#
#                                               MainBranch Hobbyist  \
# 5      I am not primarily a developer, but I write co...      Yes
# 8                         I am a developer by profession      Yes
# 12                        I am a developer by profession      Yes
# 15                        I am a developer by profession      Yes
# 21                        I am a developer by profession      Yes
# ...                                                  ...      ...
# 88323                     I am a developer by profession      Yes
# ...

# %%
##USED TO GET THE RECORDS OF ConvertedComp and Country
df[['ConvertedComp','Country']]
# Out:
#        ConvertedComp                 Country
# 0                NaN          United Kingdom
# 1                NaN  Bosnia and Herzegovina
# 2             8820.0                   INDIA
# 3            61000.0           United States
# 4                NaN                 Ukraine
# ...              ...                     ...
# 88878            NaN                  Canada
# 88879            NaN                     NaN
# 88880            NaN                     NaN
# 88881            NaN                     NaN
# 88882            NaN                   Spain
#
# [88883 rows x 2 columns]

# %%
##USED TO SORT THE COUNTRY BY ASCENDING ORDER
df.sort_values(by =['Country','ConvertedComp'],ascending =[True,False], inplace = True)

# %%
df[['Country','ConvertedComp']].head(5)
# Out:
#            Country  ConvertedComp
# 62723  Afghanistan      1000000.0
# 50172  Afghanistan       153216.0
# 39018  Afghanistan        19152.0
# 58082  Afghanistan        17556.0
# 7056   Afghanistan        14364.0

# %%
##USED TO DISPLAY THE INITIAL 19 LARGEST SALARY
df['ConvertedComp'].nlargest(19)
# Out:
# 25833    2000000.0
# 87353    2000000.0
# 21895    2000000.0
# 28080    2000000.0
# 72274    2000000.0
# 77665    2000000.0
# 79701    2000000.0
# 51798    2000000.0
# 75088    2000000.0
# 32056    2000000.0
# 83866    2000000.0
# 57       2000000.0
# 101      2000000.0
# 164      2000000.0
# 434      2000000.0
# 450      2000000.0
# 489      2000000.0
# 537      2000000.0
# 767      2000000.0
# Name: ConvertedComp, dtype: float64

# %%
##USED TO DISPLAY THE 10 LARGEST SALARY ALONG WITH THEIR RECORDS
df_10_largest=df.nlargest(10,'ConvertedComp')
df_10_largest
# Out:
#            Country  Respondent  \
# 25833       Canada       25983
# 87353      Germany       87896
# 21895        India       22013
# 28080        India       28243
# 72274        India       72732
# 77665       Mexico       78151
# 79701  Netherlands       80200
# 51798         Peru       52132
# 75088    Singapore       75561
# 32056  Switzerland       32250
#
#                                               MainBranch Hobbyist  \
# 25833                     I am a developer by profession      Yes
# 87353                     I am a developer by profession      Yes
# 21895                     I am a developer by profession      Yes
# 28080                     I am a developer by profession      Yes
# 72274  I am not primarily a developer, but I write co...       No
# 77665                     I am a developer by profession      Yes
# 79701                     I am a developer by profession      Yes
# 51798                     I am a developer by profession      Yes
# ...

# %%
##USED TO DISPLAY THE DATA TYPES OF EACH COLUMN
df.dtypes
# Out:
# Country         object
# Respondent       int64
# MainBranch      object
# Hobbyist        object
# OpenSourcer     object
#                  ...
# Sexuality       object
# Ethnicity       object
# Dependents      object
# SurveyLength    object
# SurveyEase      object
# Length: 85, dtype: object

# %%
##USED TO GET MEDIAN VALUE 
df_median =df['ConvertedComp'].median()
df_median
# Out:
# 57287.0

# %%
##USED TO COUNT THE RECORD
df_count=df['SocialMedia'].value_counts()
df_count
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
##USED TO DISPLAY THE INDIVIDUAL PERCENT OF EACH SOCIAL MEDIA
df_percent=df['SocialMedia'].value_counts(normalize = True)
df_percent
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
##USED TO GROUP THE COUNTRY
country_grp=df.groupby(['Country'])

# %%
country_grp

# %%
##USED TO GET THE PARTICULAR COUNTRY
country_grp.get_group('India')
# Out:
#       Country  Respondent                                         MainBranch  \
# 21895   India       22013                     I am a developer by profession
# 28080   India       28243                     I am a developer by profession
# 72274   India       72732  I am not primarily a developer, but I write co...
# 16703   India       16793                     I am a developer by profession
# 52225   India       52561                     I am a developer by profession
# ...       ...         ...                                                ...
# 88808   India       77339                                                NaN
# 88825   India       79795                                                NaN
# 88852   India       83862                                                NaN
# 88853   India       84299                                                NaN
# 88864   India       86012                                                NaN
#
# ...

# %%
##USED TO DISPLAY THE SOCIAL MEDIA USED BY EACH COUNTRY
country_grp_media=country_grp['SocialMedia'].value_counts()

# %%
country_grp_media
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#                                          ..
# Zimbabwe     Facebook                     3
#              YouTube                      3
#              Instagram                    2
#              LinkedIn                     2
#              Reddit                       1
# Name: SocialMedia, Length: 1221, dtype: int64

# %%
##USED TO DSPLAY THE SOCIAL MEDIA USED BY COUNTRY INDIA
country_grp_india =country_grp['SocialMedia'].value_counts().loc['India']
country_grp_india
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
##USET TO DISPLAY THE MEAN AND MEDIAN VALUE OF COUNTRY INDIA
country_grp['ConvertedComp'].agg(['median','mean']).loc['India']
# Out:
# median    10080.000000
# mean      28057.664916
# Name: India, dtype: float64

# %%
df_india=df['Country']=='India'

# %%
##USED TO DISPLAY THE PYTHON DEVELOPERS IN INDIA
python_india=df[df_india]['LanguageWorkedWith'].str.contains('Python')
python_india
# Out:
# 21895     True
# 28080     True
# 72274     True
# 16703     True
# 52225    False
#          ...
# 88808    False
# 88825     True
# 88852    False
# 88853     True
# 88864    False
# Name: LanguageWorkedWith, Length: 9061, dtype: object

# %%
##USED TO COUNT THE PYTHON DEVELOPERS IN INDIA
python_india_sum=df[df_india]['LanguageWorkedWith'].str.contains('Python').sum()
python_india_sum
# Out:
# 3105

# %%
##USED TO DISPLAY THE EACH COUNTRY WITH INDIVIDUAL LANGUAGE USED 
country_language_python=country_grp['LanguageWorkedWith'].apply(lambda x:x.str.contains('Python').sum())
country_language_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 180, dtype: int64

# %%
country_resp=df['Country'].value_counts()

# %%
##USED TO MERGE THE TWO RECORDS 
pythonconcat=pd.concat([country_resp,country_language_python],axis='columns',sort = False)
pythonconcat
# Out:
#                                   Country  LanguageWorkedWith
# United States                       20949               10083
# India                                9061                3105
# Germany                              5866                2451
# United Kingdom                       5737                2384
# Canada                               3395                1558
# ...                                   ...                 ...
# Saint Vincent and the Grenadines        1                   0
# Saint Kitts and Nevis                   1                   0
# INDIA                                   1                   0
# Chad                                    1                   0
# North Korea                             1                   0
#
# [180 rows x 2 columns]

# %%
pythonconcat.rename(columns ={'Country':'Numresp','LanguageWorkedWith':'Knowspython'},inplace =True)

# %%
pythonconcat
# Out:
#                                   Numresp  Knowspython
# United States                       20949        10083
# India                                9061         3105
# Germany                              5866         2451
# United Kingdom                       5737         2384
# Canada                               3395         1558
# ...                                   ...          ...
# Saint Vincent and the Grenadines        1            0
# Saint Kitts and Nevis                   1            0
# INDIA                                   1            0
# Chad                                    1            0
# North Korea                             1            0
#
# [180 rows x 2 columns]

# %%
##USED TO GET THE PERCENTAGE OF DEVELOPERS KNOWS PYTHON
pythonconcat['PctKnowsPython']=(pythonconcat['Knowspython']/pythonconcat['Numresp'])*100

# %%
pythonconcat['PctKnowsPython']
# Out:
# United States                       48.131176
# India                               34.267741
# Germany                             41.783157
# United Kingdom                      41.554820
# Canada                              45.891016
#                                       ...
# Saint Vincent and the Grenadines     0.000000
# Saint Kitts and Nevis                0.000000
# INDIA                                0.000000
# Chad                                 0.000000
# North Korea                          0.000000
# Name: PctKnowsPython, Length: 180, dtype: float64

# %%
pythonconcat
# Out:
#                                   Numresp  Knowspython  PctKnowsPython
# United States                       20949        10083       48.131176
# India                                9061         3105       34.267741
# Germany                              5866         2451       41.783157
# United Kingdom                       5737         2384       41.554820
# Canada                               3395         1558       45.891016
# ...                                   ...          ...             ...
# Saint Vincent and the Grenadines        1            0        0.000000
# Saint Kitts and Nevis                   1            0        0.000000
# INDIA                                   1            0        0.000000
# Chad                                    1            0        0.000000
# North Korea                             1            0        0.000000
#
# [180 rows x 3 columns]

# %%
##USED TO DISPLAY  THE MAXIMUM PERCENTAGE OF PYTHON DEVELOPERS IN ORDER
pythonconcat.sort_values(by ='PctKnowsPython',ascending =False,inplace =True)

# %%
pythonconcat
# Out:
#                        Numresp  Knowspython  PctKnowsPython
# Sao Tome and Principe        1            1      100.000000
# Timor-Leste                  1            1      100.000000
# Dominica                     1            1      100.000000
# Niger                        1            1      100.000000
# Turkmenistan                 7            6       85.714286
# ...                        ...          ...             ...
# Saint Kitts and Nevis        1            0        0.000000
# INDIA                        1            0        0.000000
# Malawi                       2            0        0.000000
# Chad                         1            0        0.000000
# North Korea                  1            0        0.000000
#
# [180 rows x 3 columns]

# %%
##USED TO DISPLAY THE PYTHON USERS IN INDIA
pythonconcat.loc['India']
# Out:
# Numresp           9061.000000
# Knowspython       3105.000000
# PctKnowsPython      34.267741
# Name: India, dtype: float64

# %%
##USED TO DISPLAY THE UNIQUE YEARS 
df['YearsCode'].unique()
# Out:
# array(['Less than 1 year', '7', '2', '6', '3', '4', '10', '36', '1', nan,
#        'More than 50 years', '20', '9', '5', '8', '31', '28', '15', '13',
#        '12', '17', '18', '21', '35', '14', '25', '11', '19', '22', '23',
#        '40', '39', '30', '43', '27', '33', '29', '24', '34', '16', '32',
#        '26', '38', '44', '41', '45', '37', '47', '42', '46', '48', '50',
#        '49'], dtype=object)

# %%
##USED TO REPLACE THE VALUES
df['YearsCode'].replace('More than 50 years',50,inplace = True)

# %%
df['YearsCode'].replace('Less than 1 year',1,inplace = True)

# %%
df['YearsCode'].unique()
# Out:
# array([1, '7', '2', '6', '3', '4', '10', '36', '1', nan, '20', '9', '5',
#        '8', '31', '28', '15', '13', '12', '17', '18', '21', '35', '14',
#        '25', '11', '19', '22', '23', '40', '39', '30', '43', '27', '33',
#        '29', '24', '34', '16', '32', '26', '38', '44', '41', '45', '37',
#        '47', '42', '46', '48', '50', '49'], dtype=object)

# %%
##USED TO CHANGE THE DATA TYPE
df['YearsCode'].astype(float)
# Out:
# 62723    1.0
# 50172    7.0
# 39018    2.0
# 58082    6.0
# 7056     7.0
#         ...
# 88873    NaN
# 88874    NaN
# 88879    NaN
# 88880    NaN
# 88881    NaN
# Name: YearsCode, Length: 88883, dtype: float64

# %%
##USED TO DROP THE NAN VALUES IN RECORDS
df.dropna()
# Out:
#          Country  Respondent  \
# 9230     Albania        9270
# 13322    Albania       13385
# 11496    Albania       11549
# 63960    Algeria       64369
# 67927  Argentina       68362
# ...          ...         ...
# 27033   Viet Nam       27191
# 46285   Viet Nam       46585
# 34898   Viet Nam       35116
# 70227   Viet Nam       70673
# 20465   Viet Nam       20580
#
#                                               MainBranch Hobbyist  \
# 9230                      I am a developer by profession       No
# 13322                     I am a developer by profession      Yes
# 11496                     I am a developer by profession      Yes
# 63960                     I am a developer by profession      Yes
# 67927                     I am a developer by profession      Yes
# ...                                                  ...      ...
# 27033                     I am a developer by profession      Yes
# 46285  I am not primarily a developer, but I write co...       No
# ...

# %%
#df.dropna(axis = 'index',how ='any') --- Used to remove nan value when any of the value in DF is nan

#df.dropna(axis = 'index',,how ='all') --- Used to remove nan value when all index(rows) are nan

#df.dropna(axis = 'columns',how ='all') --- Used to remove nan values  all column in df have nan

# %% [markdown]
# # FOUR METHODS TO CHANGE ROWS AND COLUMNS
#
# apply
# map
# applymap
# replace

# %%
##USED TO COUNT THE NO OF WORDS IN HOBBYIST
##APPLY IS USED IN SERIES
df['Hobbyist'].apply(len)
# Out:
# 62723    3
# 50172    3
# 39018    3
# 58082    3
# 7056     3
#         ..
# 88873    2
# 88874    2
# 88879    2
# 88880    2
# 88881    2
# Name: Hobbyist, Length: 88883, dtype: int64

# %%
##MAP IS USED IN DATAFRAME
##USED TO CHANGE THE RECORDS IN HOBBYIST COLUMN
df['Hobbyist'].map({'Yes':True,'No':False})
# Out:
# 62723     True
# 50172     True
# 39018     True
# 58082     True
# 7056      True
#          ...
# 88873    False
# 88874    False
# 88879    False
# 88880    False
# 88881    False
# Name: Hobbyist, Length: 88883, dtype: bool
